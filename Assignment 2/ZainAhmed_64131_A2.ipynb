# %% [markdown]
# ### Student Details Who Performed This Code:
#    ##### - Student Name & ID: Zain Ahmed Siddiqui (64131)
#    <hr>

# %%
import pandas as pd
import random
import numpy as np

# %%
df = pd.read_csv('test.csv')

# %%
id_testdf = df[['id']]

id_testdf.insert(1, 'target', 0)
id_testdf['target'] = np.random.rand(700000,1)
# Out:
# <ipython-input-4-cd61e5ad55f8>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   id_testdf['target'] = np.random.rand(700000,1)

# %%
id_testdf.to_csv('submitdataByZain.csv', index=False)

# %%
id_testdf.head()
# Out:
#        id    target
# 0  900000  0.301379
# 1  900001  0.838622
# 2  900002  0.997288
# 3  900003  0.050734
# 4  900004  0.845309

# %% [markdown]
# ![zain.PNG](attachment:zain.PNG)
