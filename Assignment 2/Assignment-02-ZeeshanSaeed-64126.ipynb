# %% [markdown]
# ### Zeeshan Bin Saeed 64126
#    <hr>

# %%
import pandas as pd
import random
import numpy as np

# %%
df = pd.read_csv('test.csv')

id_testdf = df[['id']]

id_testdf.insert(1, 'target', 0)
id_testdf['target'] = np.random.rand(700000,1)

id_testdf.to_csv('zeeshanTest.csv', index=False)
# Out:
# <ipython-input-3-f5e2ed090845>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   id_testdf['target'] = np.random.rand(700000,1)

# %%
print(id_testdf.head())
# Out:
#        id    target
# 0  900000  0.259238
# 1  900001  0.575186
# 2  900002  0.455621
# 3  900003  0.963766
# 4  900004  0.353693

# %% [markdown]
# ![zeeshan.PNG](attachment:zeeshan.PNG)
